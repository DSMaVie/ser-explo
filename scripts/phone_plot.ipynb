# %%
import pandas as pd

data = pd.read_csv("/work/smt4/thulke/vieweg/SER/Code/sisyphus/work/preprocessing/ie4_w2v_clf/IEM4ProcessorForWav2Vec2WithText.pDfdwlBxUznE/output/preprocessed_data/manifest.csv")

# %%
data
# Out:
#       Unnamed: 0                file_idx  \
# 0              0  Ses04F_script02_1_M000
# 1              2  Ses04F_script02_1_F000
# 2              3  Ses04F_script02_1_M002
# 3             14  Ses04F_script02_1_M009
# 4             16  Ses04F_script02_1_M010
# ...          ...                     ...
# 2582       10028  Ses01M_script01_1_F041
# 2583       10029  Ses01M_script01_1_M041
# 2584       10030  Ses01M_script01_1_F042
# 2585       10031  Ses01M_script01_1_M042
# 2586       10032  Ses01M_script01_1_F043
#
#                                              transcript  Session  Recording  \
# 0     What time is it They're supposed to run around...        4          2
# 1                                                  Fine        4          2
# 2     Is that is thatthat's just foam isn't it I can...        4          2
# 3     I hope the moon stays out I wonder do they alw...        4          2
# 4     Are you cold Do you want my jacket We should h...        4          2
# ...

# %%
phone_data = data.phonemes.values

# %%
from collections import Counter

# %%
from itertools import chain
count = Counter(chain(phones.split(" ") for phones in phone_data))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 from itertools import chain
# ----> 2 count = Counter(chain(phones.split(" ") for phones in phone_data))
#
# File /work/tools/asr/python/3.8.0/lib/python3.8/collections/__init__.py:552, in Counter.__init__(self, iterable, **kwds)
#     <a href='file:///work/tools/asr/python/3.8.0/lib/python3.8/collections/__init__.py?line=540'>541</a> '''Create a new, empty Counter object.  And if given, count elements
#     <a href='file:///work/tools/asr/python/3.8.0/lib/python3.8/collections/__init__.py?line=541'>542</a> from an input iterable.  Or, initialize the count from another mapping
#     <a href='file:///work/tools/asr/python/3.8.0/lib/python3.8/collections/__init__.py?line=542'>543</a> of elements to their counts.
#    (...)
# ...

# %%
count = Counter([phone for phones in phone_data for phone in phones.split(" ")])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 count = Counter([phone for phones in phone_data for phone in phones.split(" ")])
#
# Cell In[6], line 1, in <listcomp>(.0)
# ----> 1 count = Counter([phone for phones in phone_data for phone in phones.split(" ")])
#
# AttributeError: 'float' object has no attribute 'split'

# %%
phone_Data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 phone_Data
#
# NameError: name 'phone_Data' is not defined

# %%
phone_data
# Out:
# array(['w ʌ t | t aɪ m | ɪ z | ɪ t | ð eɪ ɚ | s ə p oʊ z d | t ə | ɹ ʌ n | ɚ ɹ aʊ n d | m ɪ d n aɪ t | ð ɪ s | ɪ z | ɡ ɹ eɪ t | ɪ z ə n t | ɪ t | l ʊ k | æ t | ð ɪ s | n aɪ t | w iː v | ɡ ɑː t | h ɪ ɹ | ɪ t | k ʊ d ə n t | b iː | b ɛ ɾ ɚ |',
#        'f aɪ n |',
#        'ɪ z | ð æ t | ɪ z | θ æ t θ æ t s | dʒ ʌ s t | f oʊ m | ɪ z ə n t | ɪ ɾ | aɪ | k æ n t | iː v ə n | t ɛ l |',
#        ..., 'aɪ | d oʊ n t | ʌ n d ɚ s t æ n d | j uː | d uː | aɪ |',
#        'n oʊ | j uː | d oʊ n t | aɪ m | ɐ | p ɹ ɪ ɾ i | t ʌ f | ɡ aɪ |',
#        'w ɛ l | aɪ | k æ n | s iː | ð æ t |'], dtype=object)

# %%
[phones.split(" ") for phones in phone_data]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 [phones.split(" ") for phones in phone_data]
#
# Cell In[9], line 1, in <listcomp>(.0)
# ----> 1 [phones.split(" ") for phones in phone_data]
#
# AttributeError: 'float' object has no attribute 'split'

# %%
phones
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 phones
#
# NameError: name 'phones' is not defined

# %%
for phones in phone_data:
    print(type(phones))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
for phones in phone_data:
    if isinstance(phones, float):
        print(phones)
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
data
# Out:
#       Unnamed: 0                file_idx  \
# 0              0  Ses04F_script02_1_M000
# 1              2  Ses04F_script02_1_F000
# 2              3  Ses04F_script02_1_M002
# 3             14  Ses04F_script02_1_M009
# 4             16  Ses04F_script02_1_M010
# ...          ...                     ...
# 2582       10028  Ses01M_script01_1_F041
# 2583       10029  Ses01M_script01_1_M041
# 2584       10030  Ses01M_script01_1_F042
# 2585       10031  Ses01M_script01_1_M042
# 2586       10032  Ses01M_script01_1_F043
#
#                                              transcript  Session  Recording  \
# 0     What time is it They're supposed to run around...        4          2
# 1                                                  Fine        4          2
# 2     Is that is thatthat's just foam isn't it I can...        4          2
# 3     I hope the moon stays out I wonder do they alw...        4          2
# 4     Are you cold Do you want my jacket We should h...        4          2
# ...

# %%
data[data.phonemes.isna()]
# Out:
#       Unnamed: 0                file_idx transcript  Session  Recording  \
# 832         2885  Ses03F_script03_1_F000        NaN        3          3
# 2038        8649  Ses01F_script01_3_F010        NaN        1          1
# 2040        8651  Ses01F_script01_3_F011        NaN        1          1
# 2042        8653  Ses01F_script01_3_F012        NaN        1          1
# 2092        8751  Ses01F_script03_1_F020        NaN        1          3
# 2100        8772  Ses01F_script03_1_M036        NaN        1          3
# 2301        9514  Ses01M_script03_1_F007        NaN        1          3
# 2306        9520  Ses01M_script03_1_F010        NaN        1          3
# 2431        9744  Ses01F_script02_2_M043        NaN        1          2
# 2435        9749  Ses01F_script02_2_M046        NaN        1          2
# 2520        9901  Ses01F_script02_1_F009        NaN        1          2
# 2549        9958  Ses01M_script01_1_F006        NaN        1          1
#
# ...

# %%
data  = data.drop(data.phonemes.isna())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 data  = data.drop(data.phonemes.isna())
#
# File /work/smt4/thulke/vieweg/SER/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///work/smt4/thulke/vieweg/SER/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py?line=324'>325</a> if len(args) > num_allow_args:
#     <a href='file:///work/smt4/thulke/vieweg/SER/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py?line=325'>326</a>     warnings.warn(
#     <a href='file:///work/smt4/thulke/vieweg/SER/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py?line=326'>327</a>         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
data  = data.drop(data.phonemes.isna().index)

# %%
count = Counter([phone for phones in data.phonemes.values for phone in phones.split(" ")])

# %%
count
# Out:
# Counter()

# %%
[phone for phones in data.phonemes.values for phone in phones.split(" ")]
# Out:
# []

# %%
data.phonemes.str.split(" ")
# Out:
# Series([], Name: phonemes, dtype: object)

# %%
data.phonemes
# Out:
# Series([], Name: phonemes, dtype: object)

# %%
data
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, file_idx, transcript, Session, Recording, Gender, Repetition, Emotion, split, duration, phonemes]
# Index: []

# %%
import pandas as pd

data = pd.read_csv("/work/smt4/thulke/vieweg/SER/Code/sisyphus/work/preprocessing/ie4_w2v_clf/IEM4ProcessorForWav2Vec2WithText.pDfdwlBxUznE/output/preprocessed_data/manifest.csv")

# %%
data.phonemes.isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2582    False
# 2583    False
# 2584    False
# 2585    False
# 2586    False
# Name: phonemes, Length: 2587, dtype: bool

# %%
data.phonemes.isna().sum()
# Out:
# 12

# %%
data.drop(index=data.phonemes.isna())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 data.drop(index=data.phonemes.isna())
#
# File /work/smt4/thulke/vieweg/SER/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///work/smt4/thulke/vieweg/SER/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py?line=324'>325</a> if len(args) > num_allow_args:
#     <a href='file:///work/smt4/thulke/vieweg/SER/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py?line=325'>326</a>     warnings.warn(
#     <a href='file:///work/smt4/thulke/vieweg/SER/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py?line=326'>327</a>         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
data.drop(rows=data.phonemes.isna())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 data.drop(rows=data.phonemes.isna())
#
# File /work/smt4/thulke/vieweg/SER/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///work/smt4/thulke/vieweg/SER/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py?line=324'>325</a> if len(args) > num_allow_args:
#     <a href='file:///work/smt4/thulke/vieweg/SER/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py?line=325'>326</a>     warnings.warn(
#     <a href='file:///work/smt4/thulke/vieweg/SER/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py?line=326'>327</a>         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
data.drop(data.phonemes.isna())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 data.drop(data.phonemes.isna())
#
# File /work/smt4/thulke/vieweg/SER/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///work/smt4/thulke/vieweg/SER/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py?line=324'>325</a> if len(args) > num_allow_args:
#     <a href='file:///work/smt4/thulke/vieweg/SER/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py?line=325'>326</a>     warnings.warn(
#     <a href='file:///work/smt4/thulke/vieweg/SER/.venv/lib/python3.8/site-packages/pandas/util/_decorators.py?line=326'>327</a>         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
len(data)
# Out:
# 2587

# %%
data = data.dropna()

# %%
len(data)
# Out:
# 2575

# %%
count = Counter([phone for phones in data.phonemes.values for phone in phones.split(" ")])

# %%
count
# Out:
# Counter({'w': 2755,
#          'ʌ': 2887,
#          't': 7426,
#          '|': 30396,
#          'aɪ': 3192,
#          'm': 3106,
#          'ɪ': 6201,
#          'z': 2220,
#          'ð': 2803,
#          'eɪ': 1420,
#          'ɚ': 1167,
#          's': 4447,
#          'ə': 2704,
#          'p': 1253,
#          'oʊ': 2132,
#          'd': 4109,
#          'ɹ': 2441,
#          'n': 6356,
#          'aʊ': 675,
#          'ɡ': 1132,
#          'l': 3253,
#          'ʊ': 673,
#          'k': 2626,
#          'æ': 3480,
#          'iː': 1975,
#          'v': 1585,
#          'ɑː': 965,
#          'h': 1587,
#          'b': 1803,
#          'ɛ': 2408,
#          'ɾ': 860,
#          'f': 1552,
#          'θ': 686,
#          'dʒ': 467,
#          'uː': 2211,
#          'ɔː': 592,
#          'ʊɹ': 225,
#          'ŋ': 1558,
#          'ɐ': 1108,
#          'ᵻ': 484,
#          'j': 1998,
#          'ɪɹ': 282,
#          'ɑːɹ': 286,
#          'ɔ': 572,
#          'ʃ': 552,
# ...

# %%
labels, values = zip(*count.items())

# %%
indexes = np.arange(len(labels))
width = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 indexes = np.arange(len(labels))
#       2 width = 1
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
indexes = np.arange(len(labels))
width = 1

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.bar(indexes, values, width)
plt.xticks(indexes + width * 0.5, labels)
plt.show()
